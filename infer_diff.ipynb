# %% [markdown]
# inference

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset
from model import *
from data import *
from utils import *

pth_save_path = './example/diff/pth/'

mol2input = Mol2Input()
device = torch.device("cuda:0" if torch.cuda.is_available() else torch.device('cpu'))
fitting_model = FittingNet(output_dim=1)
unimol_model = UniMolModel(output_dim=1, data_type='molecule', remove_hs=False)
fitting_model.load_state_dict(torch.load(pth_save_path +'atomic_fit_nh.pth'))
unimol_model.load_state_dict(torch.load(pth_save_path + 'atomic_model_nh.pth'))
fitting_model.to(device)
fitting_model.eval()
unimol_model.to(device)
unimol_model.eval()
print('Load model successfully!')
# Out:
# 2024-11-25 04:02:47 | model/unimol.py | 114 | INFO | Uni-Mol(QSAR) | Loading pretrained weights from /vepfs/fs_users/ycjin/ads_predict_tools/weights/mol_pre_all_h_220816.pt
# Load model successfully!

# %% [markdown]
# 单项预测

# %%
from ase import Atoms
from ase.io import read,write
import py3Dmol
from ase.io import read

input_file = './example/pub25/data/xyz/400.xyz' # input molecule file
atom = read(input_file)

# 去除H原子
sym = np.array(atom.get_chemical_symbols())
coord = [torch.tensor(atom.get_positions())[sym != 'H']]
atype = [np.array(atom.get_chemical_symbols())[sym != 'H']]
atom = atom[sym != 'H']

# 预测
input_dict = mol2input.coord2unimol_inputs(coord,atype)
for k in input_dict.keys(): input_dict[k] = input_dict[k].to(device)
atomic_reprs = unimol_model(return_repr=True,**input_dict)['atomic_reprs']
pred = []
for repr in atomic_reprs:
    atomic_p = fitting_model(repr)
    p = torch.sum(fitting_model(repr))

print(atomic_p)# 原子贡献
print(p)# 总能量


# 可视化
value = np.array(atomic_p.detach().cpu()).reshape(-1)
value = (value-np.min(value))/(np.max(value)-np.min(value)) * 200+50
value = np.int16(value)


setting = {
    'H':[0.3],
    'C':[0.3],
    'O':[0.3],
    'N':[0.3],
    'S':[0.3],
    'F':[0.3],
    'Cl':[0.3],
    'Br':[0.3],
    'I':[0.3]
}

def self_hex(n):
    return hex(n)[2:].zfill(2)

write('md_n.xyz', atom)

# 贡献图
view = py3Dmol.view(width=300, height=300)
view.addModel(open('md_n.xyz').read(), format='xyz')
for i,type in enumerate(atype[0]):
    view.setStyle({'index':i}, {'sphere': {'scale':setting[type][0],'color':'#'+self_hex(value[i])+self_hex(value[i])+self_hex(value[i])}})
view.zoomTo(animate=True)
view.show()

# 分子图
view_2 = py3Dmol.view(width=300, height=300)
view_2.addModel(open('md_n.xyz').read(), format='xyz')
view.setStyle({'sphere': {'scale': 0.3}})
view.zoomTo(animate=True)
view.show()
# Out:
# tensor([[0.1258],
#         [0.1808],
#         [0.1754],
#         [0.1441],
#         [0.1706],
#         [0.2468],
#         [0.1925],
#         [0.1744],
#         [0.1812],
#         [0.1226],
#         [0.2878],
#         [0.2340],
#         [0.1205],
#         [0.2017],
#         [0.1549],
#         [0.1397],
#         [0.1510],
#         [0.1292],
#         [0.1402],
#         [0.1180],
#         [0.1076],
#         [0.1383],
#         [0.1149],
#         [0.1587],
#         [0.2012]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor(4.1119, device='cuda:0', grad_fn=<SumBackward0>)
# <div id="3dmolviewer_17325073682377794"  style="position: relative; width: 300px; height: 300px;">
#         <p id="3dmolwarning_17325073682377794" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.1.0/3Dmol-min.js');
# }
#
# var viewer_17325073682377794 = null;
# var warn = document.getElementById("3dmolwarning_17325073682377794");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17325073682377794 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17325073682377794"),{backgroundColor:"white"});
# viewer_17325073682377794.zoomTo();
# 	viewer_17325073682377794.addModel("25\nProperties=species:S:1:pos:R:3 482737030=T pbc=\"F F F\"\nC        5.18296500       1.88343300       3.65420400\nO        4.35993000       2.55419600       2.71120400\nC        3.20836500       1.92536400       2.30786800\nC        2.80685600       0.65860800       2.74016600\nC        1.61463200       0.09724400       2.27307200\nC        0.80016200       0.79190800       1.37166800\nC        1.21021300       2.06039200       0.93100400\nC        2.40303900       2.63294900       1.39341000\nO        2.87017400       3.86661800       1.01048800\nC        2.06530500       4.63659300       0.12936500\nC       -0.44787600       0.17542700       0.88376200\nC       -1.59755500       0.85947300       0.83488500\nC       -2.82127900       0.19966000       0.34412500\nO       -3.85923800       0.84497000       0.30215300\nC       -2.68609900      -1.21606400      -0.06804100\nC       -3.74712700      -1.98247400      -0.56060400\nO       -5.00359500      -1.44542400      -0.68971300\nC       -3.56943300      -3.32915700      -0.94233600\nO       -4.72480200      -3.91470800      -1.40028600\nC       -4.67618200      -5.27403400      -1.81102100\nC       -2.29790000      -3.89945800      -0.82181000\nO       -2.05812800      -5.19729500      -1.17588000\nC       -1.23208600      -3.14143900      -0.32988700\nC       -1.42917700      -1.80887600       0.04368000\nO       -0.31956600      -1.15085200       0.51538700\n");
# 	viewer_17325073682377794.setStyle({"index": 0},{"sphere": {"scale": 0.3, "color": "#464646"}});
# 	viewer_17325073682377794.setStyle({"index": 1},{"sphere": {"scale": 0.3, "color": "#838383"}});
# 	viewer_17325073682377794.setStyle({"index": 2},{"sphere": {"scale": 0.3, "color": "#7d7d7d"}});
# 	viewer_17325073682377794.setStyle({"index": 3},{"sphere": {"scale": 0.3, "color": "#5a5a5a"}});
# 	viewer_17325073682377794.setStyle({"index": 4},{"sphere": {"scale": 0.3, "color": "#777777"}});
# 	viewer_17325073682377794.setStyle({"index": 5},{"sphere": {"scale": 0.3, "color": "#cccccc"}});
# 	viewer_17325073682377794.setStyle({"index": 6},{"sphere": {"scale": 0.3, "color": "#909090"}});
# 	viewer_17325073682377794.setStyle({"index": 7},{"sphere": {"scale": 0.3, "color": "#7c7c7c"}});
# 	viewer_17325073682377794.setStyle({"index": 8},{"sphere": {"scale": 0.3, "color": "#838383"}});
# 	viewer_17325073682377794.setStyle({"index": 9},{"sphere": {"scale": 0.3, "color": "#424242"}});
# 	viewer_17325073682377794.setStyle({"index": 10},{"sphere": {"scale": 0.3, "color": "#fafafa"}});
# 	viewer_17325073682377794.setStyle({"index": 11},{"sphere": {"scale": 0.3, "color": "#bebebe"}});
# 	viewer_17325073682377794.setStyle({"index": 12},{"sphere": {"scale": 0.3, "color": "#404040"}});
# 	viewer_17325073682377794.setStyle({"index": 13},{"sphere": {"scale": 0.3, "color": "#9a9a9a"}});
# 	viewer_17325073682377794.setStyle({"index": 14},{"sphere": {"scale": 0.3, "color": "#666666"}});
# 	viewer_17325073682377794.setStyle({"index": 15},{"sphere": {"scale": 0.3, "color": "#555555"}});
# 	viewer_17325073682377794.setStyle({"index": 16},{"sphere": {"scale": 0.3, "color": "#626262"}});
# 	viewer_17325073682377794.setStyle({"index": 17},{"sphere": {"scale": 0.3, "color": "#494949"}});
# 	viewer_17325073682377794.setStyle({"index": 18},{"sphere": {"scale": 0.3, "color": "#565656"}});
# 	viewer_17325073682377794.setStyle({"index": 19},{"sphere": {"scale": 0.3, "color": "#3d3d3d"}});
# 	viewer_17325073682377794.setStyle({"index": 20},{"sphere": {"scale": 0.3, "color": "#323232"}});
# 	viewer_17325073682377794.setStyle({"index": 21},{"sphere": {"scale": 0.3, "color": "#545454"}});
# 	viewer_17325073682377794.setStyle({"index": 22},{"sphere": {"scale": 0.3, "color": "#3a3a3a"}});
# 	viewer_17325073682377794.setStyle({"index": 23},{"sphere": {"scale": 0.3, "color": "#6a6a6a"}});
# 	viewer_17325073682377794.setStyle({"index": 24},{"sphere": {"scale": 0.3, "color": "#999999"}});
# 	viewer_17325073682377794.zoomTo();
# viewer_17325073682377794.render();
# });
# </script>
# <div id="3dmolviewer_17325073682388024"  style="position: relative; width: 300px; height: 300px;">
#         <p id="3dmolwarning_17325073682388024" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.1.0/3Dmol-min.js');
# }
#
# var viewer_17325073682388024 = null;
# var warn = document.getElementById("3dmolwarning_17325073682388024");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17325073682388024 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17325073682388024"),{backgroundColor:"white"});
# viewer_17325073682388024.zoomTo();
# 	viewer_17325073682388024.addModel("25\nProperties=species:S:1:pos:R:3 482737030=T pbc=\"F F F\"\nC        5.18296500       1.88343300       3.65420400\nO        4.35993000       2.55419600       2.71120400\nC        3.20836500       1.92536400       2.30786800\nC        2.80685600       0.65860800       2.74016600\nC        1.61463200       0.09724400       2.27307200\nC        0.80016200       0.79190800       1.37166800\nC        1.21021300       2.06039200       0.93100400\nC        2.40303900       2.63294900       1.39341000\nO        2.87017400       3.86661800       1.01048800\nC        2.06530500       4.63659300       0.12936500\nC       -0.44787600       0.17542700       0.88376200\nC       -1.59755500       0.85947300       0.83488500\nC       -2.82127900       0.19966000       0.34412500\nO       -3.85923800       0.84497000       0.30215300\nC       -2.68609900      -1.21606400      -0.06804100\nC       -3.74712700      -1.98247400      -0.56060400\nO       -5.00359500      -1.44542400      -0.68971300\nC       -3.56943300      -3.32915700      -0.94233600\nO       -4.72480200      -3.91470800      -1.40028600\nC       -4.67618200      -5.27403400      -1.81102100\nC       -2.29790000      -3.89945800      -0.82181000\nO       -2.05812800      -5.19729500      -1.17588000\nC       -1.23208600      -3.14143900      -0.32988700\nC       -1.42917700      -1.80887600       0.04368000\nO       -0.31956600      -1.15085200       0.51538700\n");
# 	viewer_17325073682388024.setStyle({"index": 0},{"sphere": {"scale": 0.3, "color": "#464646"}});
# 	viewer_17325073682388024.setStyle({"index": 1},{"sphere": {"scale": 0.3, "color": "#838383"}});
# 	viewer_17325073682388024.setStyle({"index": 2},{"sphere": {"scale": 0.3, "color": "#7d7d7d"}});
# 	viewer_17325073682388024.setStyle({"index": 3},{"sphere": {"scale": 0.3, "color": "#5a5a5a"}});
# 	viewer_17325073682388024.setStyle({"index": 4},{"sphere": {"scale": 0.3, "color": "#777777"}});
# 	viewer_17325073682388024.setStyle({"index": 5},{"sphere": {"scale": 0.3, "color": "#cccccc"}});
# 	viewer_17325073682388024.setStyle({"index": 6},{"sphere": {"scale": 0.3, "color": "#909090"}});
# 	viewer_17325073682388024.setStyle({"index": 7},{"sphere": {"scale": 0.3, "color": "#7c7c7c"}});
# 	viewer_17325073682388024.setStyle({"index": 8},{"sphere": {"scale": 0.3, "color": "#838383"}});
# 	viewer_17325073682388024.setStyle({"index": 9},{"sphere": {"scale": 0.3, "color": "#424242"}});
# 	viewer_17325073682388024.setStyle({"index": 10},{"sphere": {"scale": 0.3, "color": "#fafafa"}});
# 	viewer_17325073682388024.setStyle({"index": 11},{"sphere": {"scale": 0.3, "color": "#bebebe"}});
# 	viewer_17325073682388024.setStyle({"index": 12},{"sphere": {"scale": 0.3, "color": "#404040"}});
# 	viewer_17325073682388024.setStyle({"index": 13},{"sphere": {"scale": 0.3, "color": "#9a9a9a"}});
# 	viewer_17325073682388024.setStyle({"index": 14},{"sphere": {"scale": 0.3, "color": "#666666"}});
# 	viewer_17325073682388024.setStyle({"index": 15},{"sphere": {"scale": 0.3, "color": "#555555"}});
# 	viewer_17325073682388024.setStyle({"index": 16},{"sphere": {"scale": 0.3, "color": "#626262"}});
# 	viewer_17325073682388024.setStyle({"index": 17},{"sphere": {"scale": 0.3, "color": "#494949"}});
# 	viewer_17325073682388024.setStyle({"index": 18},{"sphere": {"scale": 0.3, "color": "#565656"}});
# 	viewer_17325073682388024.setStyle({"index": 19},{"sphere": {"scale": 0.3, "color": "#3d3d3d"}});
# 	viewer_17325073682388024.setStyle({"index": 20},{"sphere": {"scale": 0.3, "color": "#323232"}});
# 	viewer_17325073682388024.setStyle({"index": 21},{"sphere": {"scale": 0.3, "color": "#545454"}});
# 	viewer_17325073682388024.setStyle({"index": 22},{"sphere": {"scale": 0.3, "color": "#3a3a3a"}});
# 	viewer_17325073682388024.setStyle({"index": 23},{"sphere": {"scale": 0.3, "color": "#6a6a6a"}});
# 	viewer_17325073682388024.setStyle({"index": 24},{"sphere": {"scale": 0.3, "color": "#999999"}});
# 	viewer_17325073682388024.zoomTo();
# 	viewer_17325073682388024.setStyle({"sphere": {"scale": 0.3}});
# 	viewer_17325073682388024.zoomTo();
# viewer_17325073682388024.render();
# });
# </script>
